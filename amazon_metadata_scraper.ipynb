# %%
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
import matplotlib.pyplot as plt
import json
from bs4 import BeautifulSoup
import pandas as pd
from scraper_tools import go_back,go_to_next_page,wait
import scraper_tools
from importlib import reload
reload(scraper_tools)
# Out:
# <module 'scraper_tools' from '/Users/cheetham/Dropbox/insight/ideas/jigsaw/scraper_tools.py'>

# %%
base_url = "https://www.amazon.com/s?i=toys-and-games&rh=n%3A165793011%2Cn%3A165795011%2Cn%3A166359011%2Cn%3A166363011%2Cp_n_feature_five_browse-bin%3A3136099011%2Cp_72%3A1248964011"
driver = webdriver.Chrome()
driver.get(base_url)
wait(amount=10) # So I can change it to the US store..

out_dir = '1000_piece/'

# %%
#

# Main loop through search pages:
for page_num in np.arange(0,0):
    # Load the page
    driver.get(base_url+"&page="+str(page_num))
    html = driver.page_source
    print(base_url+"&page="+str(page_num))
    raise Exception
    
    fname = out_dir+"results_page_{0:05}.html".format(page_num)
    with open(fname,'w') as myf:
        myf.write(html)
        
    wait(amount=2)
    print(' Done page {0}'.format(page_num))
    
print('Done!')
# Out:
# https://www.amazon.com/s?i=toys-and-games&rh=n%3A165793011%2Cn%3A165795011%2Cn%3A166359011%2Cn%3A166363011%2Cp_n_feature_five_browse-bin%3A3136099011%2Cp_72%3A1248964011&page=294
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-8-2698a041db9a> in <module>
#       7     html = driver.page_source
#       8     print(base_url+"&page="+str(page_num))
# ----> 9     raise Exception
#      10
#      11     fname = out_dir+"results_page_{0:05}.html".format(page_num)
#
# Exception:

# %%
# Scrape the metadata from the saved pages
urls = []
for page_num in np.arange(1,294):
    fname = out_dir+"results_page_{0:05}.html".format(page_num)
    with open(fname,'r') as myf:
        html = myf.read()
    soup = BeautifulSoup(html, 'html.parser')
    
    # Get the product urls
    results = soup.findAll('div',attrs={'class':'s-result-item'})

    # Loop through
    for item in results:
        item_class = item.get('class')
        # Skip the ads
        if 'AdHolder' in item_class:
            continue

        # Get the product page url and save it for later
        url = 'https://amazon.com'+item.find('a').get('href')
        
        # Strip off the trackers
        url = url.rsplit('/',1)[0]
        
        urls.append(url)
        
# Save them all
with open(out_dir+'product_urls.txt','w') as myf:
    for url in urls:
        myf.writelines(url+'\n')

# %%
reload(scraper_tools)
# Now scrape each one
with open(out_dir+'product_urls.txt','r') as myf:
    product_urls = myf.readlines()

# Set up the pandas array
reviews_df = scraper_tools.get_database()

reviews_df = reviews_df.drop([2360,2361,2362,2363,2364])

test=0
# Loop over product urls
for url_ix,product_url in enumerate(product_urls):    
    # Check if it's already filled:
    try:
        x = reviews_df['Name'][url_ix]
        if isinstance(reviews_df['Name'][url_ix],str):
            # Skip this one since it's already in the DB
            continue
        else:
            pass
    except:
        pass
    # Get the page metadata
    driver.get(product_url)
    
    item_info = scraper_tools.get_info(driver)
    
    n_saved = reviews_df.shape[0]-1
    
    if n_saved > url_ix:
        for key in item_info.keys():
            reviews_df[key][url_ix] = item_info[key]
    else:
        reviews_df = reviews_df.append(item_info,ignore_index=True)
    
    #Save it
    reviews_df.to_csv('review_db.csv')
    print(' Metadata for # {0} (saved as {1})'.format(url_ix,reviews_df.shape[0]-1))
    wait(amount=1)
# Out:
#  Metadata for # 2360 (saved as 2360)
#  Metadata for # 2361 (saved as 2361)
#  Metadata for # 2362 (saved as 2362)
#  Metadata for # 2363 (saved as 2363)
#  Metadata for # 2364 (saved as 2364)
#  Metadata for # 2365 (saved as 2365)
#  Metadata for # 2366 (saved as 2366)
#  Metadata for # 2367 (saved as 2367)
#  Metadata for # 2368 (saved as 2368)
#  Metadata for # 2369 (saved as 2369)
#  Metadata for # 2370 (saved as 2370)
#  Metadata for # 2371 (saved as 2371)
#  Metadata for # 2372 (saved as 2372)
#  Metadata for # 2373 (saved as 2373)
#  Metadata for # 2374 (saved as 2374)
#  Metadata for # 2375 (saved as 2375)
#  Metadata for # 2376 (saved as 2376)
#  Metadata for # 2377 (saved as 2377)
#  Metadata for # 2378 (saved as 2378)
#  Metadata for # 2379 (saved as 2379)
#  Metadata for # 2380 (saved as 2380)
#  Metadata for # 2381 (saved as 2381)
#  Metadata for # 2382 (saved as 2382)
#  Metadata for # 2383 (saved as 2383)
#  Metadata for # 2384 (saved as 2384)
#  Metadata for # 2385 (saved as 2385)
#  Metadata for # 2386 (saved as 2386)
#  Metadata for # 2387 (saved as 2387)
#  Metadata for # 2388 (saved as 2388)
#  Metadata for # 2389 (saved as 2389)
#  Metadata for # 2390 (saved as 2390)
#  Metadata for # 2391 (saved as 2391)
#  Metadata for # 2392 (saved as 2392)
#  Metadata for # 2393 (saved as 2393)
#  Metadata for # 2394 (saved as 2394)
#  Metadata for # 2395 (saved as 2395)
#  Metadata for # 2396 (saved as 2396)
#  Metadata for # 2397 (saved as 2397)
#  Metadata for # 2398 (saved as 2398)
#  Metadata for # 2399 (saved as 2399)
#  Metadata for # 2400 (saved as 2400)
#  Metadata for # 2401 (saved as 2401)
#  Metadata for # 2402 (saved as 2402)
#  Metadata for # 2403 (saved as 2403)
#  Metadata for # 2404 (saved as 2404)
#  Metadata for # 2405 (saved as 2405)
#  Metadata for # 2406 (saved as 2406)
#  Metadata for # 2407 (saved as 2407)
#  Metadata for # 2408 (saved as 2408)
#  Metadata for # 2409 (saved as 2409)
#  Metadata for # 2410 (saved as 2410)
#  Metadata for # 2411 (saved as 2411)
#  Metadata for # 2412 (saved as 2412)
#  Metadata for # 2413 (saved as 2413)
#  Metadata for # 2414 (saved as 2414)
#  Metadata for # 2415 (saved as 2415)
#  Metadata for # 2416 (saved as 2416)
#  Metadata for # 2417 (saved as 2417)
#  Metadata for # 2418 (saved as 2418)
#  Metadata for # 2419 (saved as 2419)
#  Metadata for # 2420 (saved as 2420)
#  Metadata for # 2421 (saved as 2421)
#  Metadata for # 2422 (saved as 2422)
#  Metadata for # 2423 (saved as 2423)
#  Metadata for # 2424 (saved as 2424)
#  Metadata for # 2425 (saved as 2425)
#  Metadata for # 2426 (saved as 2426)
#  Metadata for # 2427 (saved as 2427)
#  Metadata for # 2428 (saved as 2428)
#  Metadata for # 2429 (saved as 2429)
#  Metadata for # 2430 (saved as 2430)
#  Metadata for # 2431 (saved as 2431)
#  Metadata for # 2432 (saved as 2432)
#  Metadata for # 2433 (saved as 2433)
#  Metadata for # 2434 (saved as 2434)
#  Metadata for # 2435 (saved as 2435)
#  Metadata for # 2436 (saved as 2436)
#  Metadata for # 2437 (saved as 2437)
#  Metadata for # 2438 (saved as 2438)
#  Metadata for # 2439 (saved as 2439)
#  Metadata for # 2440 (saved as 2440)
#  Metadata for # 2441 (saved as 2441)
#  Metadata for # 2442 (saved as 2442)
#  Metadata for # 2443 (saved as 2443)
#  Metadata for # 2444 (saved as 2444)
#  Metadata for # 2445 (saved as 2445)
#  Metadata for # 2446 (saved as 2446)
#  Metadata for # 2447 (saved as 2447)
#  Metadata for # 2448 (saved as 2448)
#  Metadata for # 2449 (saved as 2449)
#  Metadata for # 2450 (saved as 2450)
#  Metadata for # 2451 (saved as 2451)
#  Metadata for # 2452 (saved as 2452)
#  Metadata for # 2453 (saved as 2453)
#  Metadata for # 2454 (saved as 2454)
#  Metadata for # 2455 (saved as 2455)
#  Metadata for # 2456 (saved as 2456)
#  Metadata for # 2457 (saved as 2457)
#  Metadata for # 2458 (saved as 2458)
#  Metadata for # 2459 (saved as 2459)
#  Metadata for # 2460 (saved as 2460)
#  Metadata for # 2461 (saved as 2461)
#  Metadata for # 2462 (saved as 2462)
#  Metadata for # 2463 (saved as 2463)
#  Metadata for # 2464 (saved as 2464)
#  Metadata for # 2465 (saved as 2465)
#  Metadata for # 2466 (saved as 2466)
#  Metadata for # 2467 (saved as 2467)
#  Metadata for # 2468 (saved as 2468)
#  Metadata for # 2469 (saved as 2469)
#  Metadata for # 2470 (saved as 2470)
#  Metadata for # 2471 (saved as 2471)
#  Metadata for # 2472 (saved as 2472)
#  Metadata for # 2473 (saved as 2473)
#  Metadata for # 2474 (saved as 2474)
#  Metadata for # 2475 (saved as 2475)
#  Metadata for # 2476 (saved as 2476)
#  Metadata for # 2477 (saved as 2477)
#  Metadata for # 2478 (saved as 2478)
#  Metadata for # 2479 (saved as 2479)
#  Metadata for # 2480 (saved as 2480)
#  Metadata for # 2481 (saved as 2481)
#  Metadata for # 2482 (saved as 2482)
#  Metadata for # 2483 (saved as 2483)
#  Metadata for # 2484 (saved as 2484)
#  Metadata for # 2485 (saved as 2485)
#  Metadata for # 2486 (saved as 2486)
#  Metadata for # 2487 (saved as 2487)
#  Metadata for # 2488 (saved as 2488)
#  Metadata for # 2489 (saved as 2489)
#  Metadata for # 2490 (saved as 2490)
#  Metadata for # 2491 (saved as 2491)
#  Metadata for # 2492 (saved as 2492)
#  Metadata for # 2493 (saved as 2493)
#  Metadata for # 2494 (saved as 2494)
#  Metadata for # 2495 (saved as 2495)
#  Metadata for # 2496 (saved as 2496)
#  Metadata for # 2497 (saved as 2497)
#  Metadata for # 2498 (saved as 2498)
#  Metadata for # 2499 (saved as 2499)
#  Metadata for # 2500 (saved as 2500)
#  Metadata for # 2501 (saved as 2501)
#  Metadata for # 2502 (saved as 2502)
#  Metadata for # 2503 (saved as 2503)
#  Metadata for # 2504 (saved as 2504)
#  Metadata for # 2505 (saved as 2505)
#  Metadata for # 2506 (saved as 2506)
#  Metadata for # 2507 (saved as 2507)
#  Metadata for # 2508 (saved as 2508)
#  Metadata for # 2509 (saved as 2509)
#  Metadata for # 2510 (saved as 2510)
#  Metadata for # 2511 (saved as 2511)
#  Metadata for # 2512 (saved as 2512)
#  Metadata for # 2513 (saved as 2513)
#  Metadata for # 2514 (saved as 2514)
#  Metadata for # 2515 (saved as 2515)
#  Metadata for # 2516 (saved as 2516)
#  Metadata for # 2517 (saved as 2517)
#  Metadata for # 2518 (saved as 2518)
#  Metadata for # 2519 (saved as 2519)
#  Metadata for # 2520 (saved as 2520)
#  Metadata for # 2521 (saved as 2521)
#  Metadata for # 2522 (saved as 2522)
#  Metadata for # 2523 (saved as 2523)
#  Metadata for # 2524 (saved as 2524)
#  Metadata for # 2525 (saved as 2525)
#  Metadata for # 2526 (saved as 2526)
#  Metadata for # 2527 (saved as 2527)
#  Metadata for # 2528 (saved as 2528)
#  Metadata for # 2529 (saved as 2529)
#  Metadata for # 2530 (saved as 2530)
#  Metadata for # 2531 (saved as 2531)
#  Metadata for # 2532 (saved as 2532)
#  Metadata for # 2533 (saved as 2533)
#  Metadata for # 2534 (saved as 2534)
#  Metadata for # 2535 (saved as 2535)
#  Metadata for # 2536 (saved as 2536)
#  Metadata for # 2537 (saved as 2537)
#  Metadata for # 2538 (saved as 2538)
#  Metadata for # 2539 (saved as 2539)
#  Metadata for # 2540 (saved as 2540)
#  Metadata for # 2541 (saved as 2541)
#  Metadata for # 2542 (saved as 2542)
#  Metadata for # 2543 (saved as 2543)
#  Metadata for # 2544 (saved as 2544)
#  Metadata for # 2545 (saved as 2545)
#  Metadata for # 2546 (saved as 2546)
#  Metadata for # 2547 (saved as 2547)
#  Metadata for # 2548 (saved as 2548)
#  Metadata for # 2549 (saved as 2549)
#  Metadata for # 2550 (saved as 2550)
#  Metadata for # 2551 (saved as 2551)
#  Metadata for # 2552 (saved as 2552)
#  Metadata for # 2553 (saved as 2553)
#  Metadata for # 2554 (saved as 2554)
#  Metadata for # 2555 (saved as 2555)
#  Metadata for # 2556 (saved as 2556)
#  Metadata for # 2557 (saved as 2557)
#  Metadata for # 2558 (saved as 2558)
#  Metadata for # 2559 (saved as 2559)
#  Metadata for # 2560 (saved as 2560)
#  Metadata for # 2561 (saved as 2561)
#  Metadata for # 2562 (saved as 2562)
#  Metadata for # 2563 (saved as 2563)
#  Metadata for # 2564 (saved as 2564)
#  Metadata for # 2565 (saved as 2565)
#  Metadata for # 2566 (saved as 2566)
#  Metadata for # 2567 (saved as 2567)
#  Metadata for # 2568 (saved as 2568)
#  Metadata for # 2569 (saved as 2569)
#  Metadata for # 2570 (saved as 2570)
#  Metadata for # 2571 (saved as 2571)
#  Metadata for # 2572 (saved as 2572)
#  Metadata for # 2573 (saved as 2573)
#  Metadata for # 2574 (saved as 2574)
#  Metadata for # 2575 (saved as 2575)
#  Metadata for # 2576 (saved as 2576)
#  Metadata for # 2577 (saved as 2577)
#  Metadata for # 2578 (saved as 2578)
#  Metadata for # 2579 (saved as 2579)
#  Metadata for # 2580 (saved as 2580)
#  Metadata for # 2581 (saved as 2581)
#  Metadata for # 2582 (saved as 2582)
#  Metadata for # 2583 (saved as 2583)
#  Metadata for # 2584 (saved as 2584)
#  Metadata for # 2585 (saved as 2585)
#  Metadata for # 2586 (saved as 2586)
#  Metadata for # 2587 (saved as 2587)
#  Metadata for # 2588 (saved as 2588)
#  Metadata for # 2589 (saved as 2589)
#  Metadata for # 2590 (saved as 2590)
#  Metadata for # 2591 (saved as 2591)
#  Metadata for # 2592 (saved as 2592)
#  Metadata for # 2593 (saved as 2593)
#  Metadata for # 2594 (saved as 2594)
#  Metadata for # 2595 (saved as 2595)
#  Metadata for # 2596 (saved as 2596)
#  Metadata for # 2597 (saved as 2597)
#  Metadata for # 2598 (saved as 2598)
#  Metadata for # 2599 (saved as 2599)
#  Metadata for # 2600 (saved as 2600)
#  Metadata for # 2601 (saved as 2601)
#  Metadata for # 2602 (saved as 2602)
#  Metadata for # 2603 (saved as 2603)
#  Metadata for # 2604 (saved as 2604)
#  Metadata for # 2605 (saved as 2605)
#  Metadata for # 2606 (saved as 2606)
#  Metadata for # 2607 (saved as 2607)
#  Metadata for # 2608 (saved as 2608)
#  Metadata for # 2609 (saved as 2609)
#  Metadata for # 2610 (saved as 2610)
#  Metadata for # 2611 (saved as 2611)
#  Metadata for # 2612 (saved as 2612)
#  Metadata for # 2613 (saved as 2613)
#  Metadata for # 2614 (saved as 2614)
#  Metadata for # 2615 (saved as 2615)
#  Metadata for # 2616 (saved as 2616)
#  Metadata for # 2617 (saved as 2617)
#  Metadata for # 2618 (saved as 2618)
#  Metadata for # 2619 (saved as 2619)
#  Metadata for # 2620 (saved as 2620)
#  Metadata for # 2621 (saved as 2621)
#  Metadata for # 2622 (saved as 2622)
#  Metadata for # 2623 (saved as 2623)
#  Metadata for # 2624 (saved as 2624)
#  Metadata for # 2625 (saved as 2625)
#  Metadata for # 2626 (saved as 2626)
#  Metadata for # 2627 (saved as 2627)
#  Metadata for # 2628 (saved as 2628)
#  Metadata for # 2629 (saved as 2629)
#  Metadata for # 2630 (saved as 2630)
#  Metadata for # 2631 (saved as 2631)
#  Metadata for # 2632 (saved as 2632)
#  Metadata for # 2633 (saved as 2633)
#  Metadata for # 2634 (saved as 2634)
#  Metadata for # 2635 (saved as 2635)
#  Metadata for # 2636 (saved as 2636)
#  Metadata for # 2637 (saved as 2637)
#  Metadata for # 2638 (saved as 2638)
#  Metadata for # 2639 (saved as 2639)
#  Metadata for # 2640 (saved as 2640)
#  Metadata for # 2641 (saved as 2641)
#  Metadata for # 2642 (saved as 2642)
#  Metadata for # 2643 (saved as 2643)
#  Metadata for # 2644 (saved as 2644)
#  Metadata for # 2645 (saved as 2645)
#  Metadata for # 2646 (saved as 2646)
#  Metadata for # 2647 (saved as 2647)
#  Metadata for # 2648 (saved as 2648)
#  Metadata for # 2649 (saved as 2649)
#  Metadata for # 2650 (saved as 2650)
#  Metadata for # 2651 (saved as 2651)
#  Metadata for # 2652 (saved as 2652)
#  Metadata for # 2653 (saved as 2653)
#  Metadata for # 2654 (saved as 2654)
#  Metadata for # 2655 (saved as 2655)
#  Metadata for # 2656 (saved as 2656)
#  Metadata for # 2657 (saved as 2657)
#  Metadata for # 2658 (saved as 2658)
#  Metadata for # 2659 (saved as 2659)
#  Metadata for # 2660 (saved as 2660)
#  Metadata for # 2661 (saved as 2661)
#  Metadata for # 2662 (saved as 2662)
#  Metadata for # 2663 (saved as 2663)
#  Metadata for # 2664 (saved as 2664)
#  Metadata for # 2665 (saved as 2665)
#  Metadata for # 2666 (saved as 2666)
#  Metadata for # 2667 (saved as 2667)
#  Metadata for # 2668 (saved as 2668)
#  Metadata for # 2669 (saved as 2669)
#  Metadata for # 2670 (saved as 2670)
#  Metadata for # 2671 (saved as 2671)
#  Metadata for # 2672 (saved as 2672)
#  Metadata for # 2673 (saved as 2673)
#  Metadata for # 2674 (saved as 2674)
#  Metadata for # 2675 (saved as 2675)
#  Metadata for # 2676 (saved as 2676)
#  Metadata for # 2677 (saved as 2677)
#  Metadata for # 2678 (saved as 2678)
#  Metadata for # 2679 (saved as 2679)
#  Metadata for # 2680 (saved as 2680)
#  Metadata for # 2681 (saved as 2681)
#  Metadata for # 2682 (saved as 2682)
#  Metadata for # 2683 (saved as 2683)
#  Metadata for # 2684 (saved as 2684)
#  Metadata for # 2685 (saved as 2685)
#  Metadata for # 2686 (saved as 2686)
#  Metadata for # 2687 (saved as 2687)
#  Metadata for # 2688 (saved as 2688)
#  Metadata for # 2689 (saved as 2689)
#  Metadata for # 2690 (saved as 2690)
#  Metadata for # 2691 (saved as 2691)
#  Metadata for # 2692 (saved as 2692)
#  Metadata for # 2693 (saved as 2693)
#  Metadata for # 2694 (saved as 2694)
#  Metadata for # 2695 (saved as 2695)
#  Metadata for # 2696 (saved as 2696)
#  Metadata for # 2697 (saved as 2697)
#  Metadata for # 2698 (saved as 2698)
#  Metadata for # 2699 (saved as 2699)
#  Metadata for # 2700 (saved as 2700)
#  Metadata for # 2701 (saved as 2701)
#  Metadata for # 2702 (saved as 2702)
#  Metadata for # 2703 (saved as 2703)
#  Metadata for # 2704 (saved as 2704)
#  Metadata for # 2705 (saved as 2705)
#  Metadata for # 2706 (saved as 2706)
#  Metadata for # 2707 (saved as 2707)
#  Metadata for # 2708 (saved as 2708)
#  Metadata for # 2709 (saved as 2709)
#  Metadata for # 2710 (saved as 2710)
#  Metadata for # 2711 (saved as 2711)
#  Metadata for # 2712 (saved as 2712)
#  Metadata for # 2713 (saved as 2713)
#  Metadata for # 2714 (saved as 2714)
#  Metadata for # 2715 (saved as 2715)
#  Metadata for # 2716 (saved as 2716)
#  Metadata for # 2717 (saved as 2717)
#  Metadata for # 2718 (saved as 2718)
#  Metadata for # 2719 (saved as 2719)
#  Metadata for # 2720 (saved as 2720)
#  Metadata for # 2721 (saved as 2721)
#  Metadata for # 2722 (saved as 2722)
#  Metadata for # 2723 (saved as 2723)
#  Metadata for # 2724 (saved as 2724)
#  Metadata for # 2725 (saved as 2725)
#  Metadata for # 2726 (saved as 2726)
#  Metadata for # 2727 (saved as 2727)
#  Metadata for # 2728 (saved as 2728)
#  Metadata for # 2729 (saved as 2729)
#  Metadata for # 2730 (saved as 2730)
#  Metadata for # 2731 (saved as 2731)
#  Metadata for # 2732 (saved as 2732)
#  Metadata for # 2733 (saved as 2733)
#  Metadata for # 2734 (saved as 2734)
#  Metadata for # 2735 (saved as 2735)
#  Metadata for # 2736 (saved as 2736)
#  Metadata for # 2737 (saved as 2737)
#  Metadata for # 2738 (saved as 2738)
#  Metadata for # 2739 (saved as 2739)
#  Metadata for # 2740 (saved as 2740)
#  Metadata for # 2741 (saved as 2741)
#  Metadata for # 2742 (saved as 2742)
#  Metadata for # 2743 (saved as 2743)
#  Metadata for # 2744 (saved as 2744)
#  Metadata for # 2745 (saved as 2745)
#  Metadata for # 2746 (saved as 2746)
#  Metadata for # 2747 (saved as 2747)
#  Metadata for # 2748 (saved as 2748)
#  Metadata for # 2749 (saved as 2749)
#  Metadata for # 2750 (saved as 2750)
#  Metadata for # 2751 (saved as 2751)
#  Metadata for # 2752 (saved as 2752)
#  Metadata for # 2753 (saved as 2753)
#  Metadata for # 2754 (saved as 2754)
#  Metadata for # 2755 (saved as 2755)
#  Metadata for # 2756 (saved as 2756)
#  Metadata for # 2757 (saved as 2757)
#  Metadata for # 2758 (saved as 2758)
#  Metadata for # 2759 (saved as 2759)
#  Metadata for # 2760 (saved as 2760)
#  Metadata for # 2761 (saved as 2761)
#  Metadata for # 2762 (saved as 2762)
#  Metadata for # 2763 (saved as 2763)
#  Metadata for # 2764 (saved as 2764)
#  Metadata for # 2765 (saved as 2765)
#  Metadata for # 2766 (saved as 2766)
#  Metadata for # 2767 (saved as 2767)
#  Metadata for # 2768 (saved as 2768)
#  Metadata for # 2769 (saved as 2769)
#  Metadata for # 2770 (saved as 2770)
#  Metadata for # 2771 (saved as 2771)
#  Metadata for # 2772 (saved as 2772)
#  Metadata for # 2773 (saved as 2773)
#  Metadata for # 2774 (saved as 2774)
#  Metadata for # 2775 (saved as 2775)
#  Metadata for # 2776 (saved as 2776)
#  Metadata for # 2777 (saved as 2777)
#  Metadata for # 2778 (saved as 2778)
#  Metadata for # 2779 (saved as 2779)
#  Metadata for # 2780 (saved as 2780)
#  Metadata for # 2781 (saved as 2781)
#  Metadata for # 2782 (saved as 2782)
#  Metadata for # 2783 (saved as 2783)
#  Metadata for # 2784 (saved as 2784)
#  Metadata for # 2785 (saved as 2785)
#  Metadata for # 2786 (saved as 2786)
#  Metadata for # 2787 (saved as 2787)
#  Metadata for # 2788 (saved as 2788)
#  Metadata for # 2789 (saved as 2789)
#  Metadata for # 2790 (saved as 2790)
#  Metadata for # 2791 (saved as 2791)
#  Metadata for # 2792 (saved as 2792)
#  Metadata for # 2793 (saved as 2793)
#  Metadata for # 2794 (saved as 2794)
#  Metadata for # 2795 (saved as 2795)
#  Metadata for # 2796 (saved as 2796)
#  Metadata for # 2797 (saved as 2797)
#  Metadata for # 2798 (saved as 2798)
#  Metadata for # 2799 (saved as 2799)
#  Metadata for # 2800 (saved as 2800)
#  Metadata for # 2801 (saved as 2801)
#  Metadata for # 2802 (saved as 2802)
#  Metadata for # 2803 (saved as 2803)
#  Metadata for # 2804 (saved as 2804)
#  Metadata for # 2805 (saved as 2805)
#  Metadata for # 2806 (saved as 2806)
#  Metadata for # 2807 (saved as 2807)
#  Metadata for # 2808 (saved as 2808)
#  Metadata for # 2809 (saved as 2809)
#  Metadata for # 2810 (saved as 2810)
#  Metadata for # 2811 (saved as 2811)
#  Metadata for # 2812 (saved as 2812)
#  Metadata for # 2813 (saved as 2813)
#  Metadata for # 2814 (saved as 2814)
#  Metadata for # 2815 (saved as 2815)
#  Metadata for # 2816 (saved as 2816)
#  Metadata for # 2817 (saved as 2817)
#  Metadata for # 2818 (saved as 2818)
#  Metadata for # 2819 (saved as 2819)
#  Metadata for # 2820 (saved as 2820)
#  Metadata for # 2821 (saved as 2821)
#  Metadata for # 2822 (saved as 2822)
#  Metadata for # 2823 (saved as 2823)
#  Metadata for # 2824 (saved as 2824)
#  Metadata for # 2825 (saved as 2825)
#  Metadata for # 2826 (saved as 2826)
#  Metadata for # 2827 (saved as 2827)
#  Metadata for # 2828 (saved as 2828)
#  Metadata for # 2829 (saved as 2829)
#  Metadata for # 2830 (saved as 2830)
#  Metadata for # 2831 (saved as 2831)
#  Metadata for # 2832 (saved as 2832)
#  Metadata for # 2833 (saved as 2833)
#  Metadata for # 2834 (saved as 2834)
#  Metadata for # 2835 (saved as 2835)
#  Metadata for # 2836 (saved as 2836)
#  Metadata for # 2837 (saved as 2837)
#  Metadata for # 2838 (saved as 2838)
#  Metadata for # 2839 (saved as 2839)
#  Metadata for # 2840 (saved as 2840)
#  Metadata for # 2841 (saved as 2841)
#  Metadata for # 2842 (saved as 2842)
#  Metadata for # 2843 (saved as 2843)
#  Metadata for # 2844 (saved as 2844)
#  Metadata for # 2845 (saved as 2845)
#  Metadata for # 2846 (saved as 2846)
#  Metadata for # 2847 (saved as 2847)
#  Metadata for # 2848 (saved as 2848)
#  Metadata for # 2849 (saved as 2849)
#  Metadata for # 2850 (saved as 2850)
#  Metadata for # 2851 (saved as 2851)
#  Metadata for # 2852 (saved as 2852)
#  Metadata for # 2853 (saved as 2853)
#  Metadata for # 2854 (saved as 2854)
#  Metadata for # 2855 (saved as 2855)
#  Metadata for # 2856 (saved as 2856)
#  Metadata for # 2857 (saved as 2857)
#  Metadata for # 2858 (saved as 2858)
#  Metadata for # 2859 (saved as 2859)
#  Metadata for # 2860 (saved as 2860)
#  Metadata for # 2861 (saved as 2861)
#  Metadata for # 2862 (saved as 2862)
#  Metadata for # 2863 (saved as 2863)
#  Metadata for # 2864 (saved as 2864)
#  Metadata for # 2865 (saved as 2865)
#  Metadata for # 2866 (saved as 2866)
#  Metadata for # 2867 (saved as 2867)
#  Metadata for # 2868 (saved as 2868)
#  Metadata for # 2869 (saved as 2869)
#  Metadata for # 2870 (saved as 2870)
#  Metadata for # 2871 (saved as 2871)
#  Metadata for # 2872 (saved as 2872)
#  Metadata for # 2873 (saved as 2873)
#  Metadata for # 2874 (saved as 2874)
#  Metadata for # 2875 (saved as 2875)
#  Metadata for # 2876 (saved as 2876)
#  Metadata for # 2877 (saved as 2877)
#  Metadata for # 2878 (saved as 2878)
#  Metadata for # 2879 (saved as 2879)
#  Metadata for # 2880 (saved as 2880)
#  Metadata for # 2881 (saved as 2881)
#  Metadata for # 2882 (saved as 2882)
#  Metadata for # 2883 (saved as 2883)
#  Metadata for # 2884 (saved as 2884)
#  Metadata for # 2885 (saved as 2885)
#  Metadata for # 2886 (saved as 2886)
#  Metadata for # 2887 (saved as 2887)
#  Metadata for # 2888 (saved as 2888)
#  Metadata for # 2889 (saved as 2889)
#  Metadata for # 2890 (saved as 2890)
#  Metadata for # 2891 (saved as 2891)
#  Metadata for # 2892 (saved as 2892)
#  Metadata for # 2893 (saved as 2893)
#  Metadata for # 2894 (saved as 2894)
#  Metadata for # 2895 (saved as 2895)
#  Metadata for # 2896 (saved as 2896)
#  Metadata for # 2897 (saved as 2897)
#  Metadata for # 2898 (saved as 2898)
#  Metadata for # 2899 (saved as 2899)
#  Metadata for # 2900 (saved as 2900)
#  Metadata for # 2901 (saved as 2901)
#  Metadata for # 2902 (saved as 2902)
#  Metadata for # 2903 (saved as 2903)
#  Metadata for # 2904 (saved as 2904)
#  Metadata for # 2905 (saved as 2905)
#  Metadata for # 2906 (saved as 2906)
#  Metadata for # 2907 (saved as 2907)
#  Metadata for # 2908 (saved as 2908)
#  Metadata for # 2909 (saved as 2909)
#  Metadata for # 2910 (saved as 2910)
#  Metadata for # 2911 (saved as 2911)
#  Metadata for # 2912 (saved as 2912)
#  Metadata for # 2913 (saved as 2913)
#  Metadata for # 2914 (saved as 2914)
#  Metadata for # 2915 (saved as 2915)
#  Metadata for # 2916 (saved as 2916)
#  Metadata for # 2917 (saved as 2917)
#  Metadata for # 2918 (saved as 2918)
#  Metadata for # 2919 (saved as 2919)
#  Metadata for # 2920 (saved as 2920)
#  Metadata for # 2921 (saved as 2921)
#  Metadata for # 2922 (saved as 2922)
#  Metadata for # 2923 (saved as 2923)
#  Metadata for # 2924 (saved as 2924)
#  Metadata for # 2925 (saved as 2925)
#  Metadata for # 2926 (saved as 2926)
#  Metadata for # 2927 (saved as 2927)
#  Metadata for # 2928 (saved as 2928)
#  Metadata for # 2929 (saved as 2929)
#  Metadata for # 2930 (saved as 2930)
#  Metadata for # 2931 (saved as 2931)
#  Metadata for # 2932 (saved as 2932)
#  Metadata for # 2933 (saved as 2933)
#  Metadata for # 2934 (saved as 2934)
#  Metadata for # 2935 (saved as 2935)
#  Metadata for # 2936 (saved as 2936)
#  Metadata for # 2937 (saved as 2937)
#  Metadata for # 2938 (saved as 2938)
#  Metadata for # 2939 (saved as 2939)
#  Metadata for # 2940 (saved as 2940)
#  Metadata for # 2941 (saved as 2941)
#  Metadata for # 2942 (saved as 2942)
#  Metadata for # 2943 (saved as 2943)
#  Metadata for # 2944 (saved as 2944)
#  Metadata for # 2945 (saved as 2945)
#  Metadata for # 2946 (saved as 2946)
#  Metadata for # 2947 (saved as 2947)
#  Metadata for # 2948 (saved as 2948)
#  Metadata for # 2949 (saved as 2949)
#  Metadata for # 2950 (saved as 2950)
#  Metadata for # 2951 (saved as 2951)
#  Metadata for # 2952 (saved as 2952)
#  Metadata for # 2953 (saved as 2953)
#  Metadata for # 2954 (saved as 2954)
#  Metadata for # 2955 (saved as 2955)
#  Metadata for # 2956 (saved as 2956)
#  Metadata for # 2957 (saved as 2957)
#  Metadata for # 2958 (saved as 2958)
#  Metadata for # 2959 (saved as 2959)
#  Metadata for # 2960 (saved as 2960)
#  Metadata for # 2961 (saved as 2961)
#  Metadata for # 2962 (saved as 2962)
#  Metadata for # 2963 (saved as 2963)
#  Metadata for # 2964 (saved as 2964)
#  Metadata for # 2965 (saved as 2965)
#  Metadata for # 2966 (saved as 2966)
#  Metadata for # 2967 (saved as 2967)
#  Metadata for # 2968 (saved as 2968)
#  Metadata for # 2969 (saved as 2969)
#  Metadata for # 2970 (saved as 2970)
#  Metadata for # 2971 (saved as 2971)
#  Metadata for # 2972 (saved as 2972)
#  Metadata for # 2973 (saved as 2973)
#  Metadata for # 2974 (saved as 2974)
#  Metadata for # 2975 (saved as 2975)
#  Metadata for # 2976 (saved as 2976)
#  Metadata for # 2977 (saved as 2977)
#  Metadata for # 2978 (saved as 2978)
#  Metadata for # 2979 (saved as 2979)
#  Metadata for # 2980 (saved as 2980)
#  Metadata for # 2981 (saved as 2981)
#  Metadata for # 2982 (saved as 2982)
#  Metadata for # 2983 (saved as 2983)
#  Metadata for # 2984 (saved as 2984)
#  Metadata for # 2985 (saved as 2985)
#  Metadata for # 2986 (saved as 2986)
#  Metadata for # 2987 (saved as 2987)
#  Metadata for # 2988 (saved as 2988)
#  Metadata for # 2989 (saved as 2989)
#  Metadata for # 2990 (saved as 2990)
#  Metadata for # 2991 (saved as 2991)
#  Metadata for # 2992 (saved as 2992)
#  Metadata for # 2993 (saved as 2993)
#  Metadata for # 2994 (saved as 2994)
#  Metadata for # 2995 (saved as 2995)
#  Metadata for # 2996 (saved as 2996)
#  Metadata for # 2997 (saved as 2997)
#  Metadata for # 2998 (saved as 2998)
#  Metadata for # 2999 (saved as 2999)
#  Metadata for # 3000 (saved as 3000)
#  Metadata for # 3001 (saved as 3001)
#  Metadata for # 3002 (saved as 3002)
#  Metadata for # 3003 (saved as 3003)
#  Metadata for # 3004 (saved as 3004)
#  Metadata for # 3005 (saved as 3005)
#  Metadata for # 3006 (saved as 3006)
#  Metadata for # 3007 (saved as 3007)
#  Metadata for # 3008 (saved as 3008)
#  Metadata for # 3009 (saved as 3009)
#  Metadata for # 3010 (saved as 3010)
#  Metadata for # 3011 (saved as 3011)
#  Metadata for # 3012 (saved as 3012)
#  Metadata for # 3013 (saved as 3013)
#  Metadata for # 3014 (saved as 3014)
#  Metadata for # 3015 (saved as 3015)
#  Metadata for # 3016 (saved as 3016)
#  Metadata for # 3017 (saved as 3017)
#  Metadata for # 3018 (saved as 3018)
#  Metadata for # 3019 (saved as 3019)
#  Metadata for # 3020 (saved as 3020)
#  Metadata for # 3021 (saved as 3021)
#  Metadata for # 3022 (saved as 3022)
#  Metadata for # 3023 (saved as 3023)
#  Metadata for # 3024 (saved as 3024)
#  Metadata for # 3025 (saved as 3025)
#  Metadata for # 3026 (saved as 3026)
#  Metadata for # 3027 (saved as 3027)
#  Metadata for # 3028 (saved as 3028)
#  Metadata for # 3029 (saved as 3029)
#  Metadata for # 3030 (saved as 3030)
#  Metadata for # 3031 (saved as 3031)
#  Metadata for # 3032 (saved as 3032)
#  Metadata for # 3033 (saved as 3033)
#  Metadata for # 3034 (saved as 3034)
#  Metadata for # 3035 (saved as 3035)
#  Metadata for # 3036 (saved as 3036)
#  Metadata for # 3037 (saved as 3037)
#  Metadata for # 3038 (saved as 3038)
#  Metadata for # 3039 (saved as 3039)
#  Metadata for # 3040 (saved as 3040)
#  Metadata for # 3041 (saved as 3041)
#  Metadata for # 3042 (saved as 3042)
#  Metadata for # 3043 (saved as 3043)
#  Metadata for # 3044 (saved as 3044)
#  Metadata for # 3045 (saved as 3045)
#  Metadata for # 3046 (saved as 3046)
#  Metadata for # 3047 (saved as 3047)
#  Metadata for # 3048 (saved as 3048)
#  Metadata for # 3049 (saved as 3049)
#  Metadata for # 3050 (saved as 3050)
#  Metadata for # 3051 (saved as 3051)
#  Metadata for # 3052 (saved as 3052)
#  Metadata for # 3053 (saved as 3053)
#  Metadata for # 3054 (saved as 3054)
#  Metadata for # 3055 (saved as 3055)
#  Metadata for # 3056 (saved as 3056)
#  Metadata for # 3057 (saved as 3057)
#  Metadata for # 3058 (saved as 3058)
#  Metadata for # 3059 (saved as 3059)
#  Metadata for # 3060 (saved as 3060)
#  Metadata for # 3061 (saved as 3061)
#  Metadata for # 3062 (saved as 3062)
#  Metadata for # 3063 (saved as 3063)
#  Metadata for # 3064 (saved as 3064)
#  Metadata for # 3065 (saved as 3065)
#  Metadata for # 3066 (saved as 3066)
#  Metadata for # 3067 (saved as 3067)
#  Metadata for # 3068 (saved as 3068)
#  Metadata for # 3069 (saved as 3069)
#  Metadata for # 3070 (saved as 3070)
#  Metadata for # 3071 (saved as 3071)
#  Metadata for # 3072 (saved as 3072)
#  Metadata for # 3073 (saved as 3073)
#  Metadata for # 3074 (saved as 3074)
#  Metadata for # 3075 (saved as 3075)
#  Metadata for # 3076 (saved as 3076)
#  Metadata for # 3077 (saved as 3077)
#  Metadata for # 3078 (saved as 3078)
#  Metadata for # 3079 (saved as 3079)
#  Metadata for # 3080 (saved as 3080)
#  Metadata for # 3081 (saved as 3081)
#  Metadata for # 3082 (saved as 3082)
#  Metadata for # 3083 (saved as 3083)
#  Metadata for # 3084 (saved as 3084)
#  Metadata for # 3085 (saved as 3085)
#  Metadata for # 3086 (saved as 3086)
#  Metadata for # 3087 (saved as 3087)
#  Metadata for # 3088 (saved as 3088)
#  Metadata for # 3089 (saved as 3089)
#  Metadata for # 3090 (saved as 3090)
#  Metadata for # 3091 (saved as 3091)
#  Metadata for # 3092 (saved as 3092)
#  Metadata for # 3093 (saved as 3093)
#  Metadata for # 3094 (saved as 3094)
#  Metadata for # 3095 (saved as 3095)
#  Metadata for # 3096 (saved as 3096)
#  Metadata for # 3097 (saved as 3097)
#  Metadata for # 3098 (saved as 3098)
#  Metadata for # 3099 (saved as 3099)
#  Metadata for # 3100 (saved as 3100)
#  Metadata for # 3101 (saved as 3101)
#  Metadata for # 3102 (saved as 3102)
#  Metadata for # 3103 (saved as 3103)
#  Metadata for # 3104 (saved as 3104)
#  Metadata for # 3105 (saved as 3105)
#  Metadata for # 3106 (saved as 3106)
#  Metadata for # 3107 (saved as 3107)
#  Metadata for # 3108 (saved as 3108)
#  Metadata for # 3109 (saved as 3109)
#  Metadata for # 3110 (saved as 3110)
#  Metadata for # 3111 (saved as 3111)
#  Metadata for # 3112 (saved as 3112)
#  Metadata for # 3113 (saved as 3113)
#  Metadata for # 3114 (saved as 3114)
#  Metadata for # 3115 (saved as 3115)
#  Metadata for # 3116 (saved as 3116)
#  Metadata for # 3117 (saved as 3117)
#  Metadata for # 3118 (saved as 3118)
#  Metadata for # 3119 (saved as 3119)
#  Metadata for # 3120 (saved as 3120)
#  Metadata for # 3121 (saved as 3121)
#  Metadata for # 3122 (saved as 3122)
#  Metadata for # 3123 (saved as 3123)
#  Metadata for # 3124 (saved as 3124)
#  Metadata for # 3125 (saved as 3125)
#  Metadata for # 3126 (saved as 3126)
#  Metadata for # 3127 (saved as 3127)
#  Metadata for # 3128 (saved as 3128)
#  Metadata for # 3129 (saved as 3129)
#  Metadata for # 3130 (saved as 3130)
#  Metadata for # 3131 (saved as 3131)
#  Metadata for # 3132 (saved as 3132)
#  Metadata for # 3133 (saved as 3133)
#  Metadata for # 3134 (saved as 3134)
#  Metadata for # 3135 (saved as 3135)
#  Metadata for # 3136 (saved as 3136)
#  Metadata for # 3137 (saved as 3137)
#  Metadata for # 3138 (saved as 3138)
#  Metadata for # 3139 (saved as 3139)
#  Metadata for # 3140 (saved as 3140)
#  Metadata for # 3141 (saved as 3141)
#  Metadata for # 3142 (saved as 3142)
#  Metadata for # 3143 (saved as 3143)
#  Metadata for # 3144 (saved as 3144)
#  Metadata for # 3145 (saved as 3145)
#  Metadata for # 3146 (saved as 3146)
#  Metadata for # 3147 (saved as 3147)
#  Metadata for # 3148 (saved as 3148)
#  Metadata for # 3149 (saved as 3149)
#  Metadata for # 3150 (saved as 3150)
#  Metadata for # 3151 (saved as 3151)
#  Metadata for # 3152 (saved as 3152)
#  Metadata for # 3153 (saved as 3153)
#  Metadata for # 3154 (saved as 3154)
#  Metadata for # 3155 (saved as 3155)
#  Metadata for # 3156 (saved as 3156)
#  Metadata for # 3157 (saved as 3157)
#  Metadata for # 3158 (saved as 3158)
#  Metadata for # 3159 (saved as 3159)
#  Metadata for # 3160 (saved as 3160)
#  Metadata for # 3161 (saved as 3161)
#  Metadata for # 3162 (saved as 3162)
#  Metadata for # 3163 (saved as 3163)
#  Metadata for # 3164 (saved as 3164)
#  Metadata for # 3165 (saved as 3165)
#  Metadata for # 3166 (saved as 3166)
#  Metadata for # 3167 (saved as 3167)
#  Metadata for # 3168 (saved as 3168)
#  Metadata for # 3169 (saved as 3169)
#  Metadata for # 3170 (saved as 3170)
#  Metadata for # 3171 (saved as 3171)
#  Metadata for # 3172 (saved as 3172)
#  Metadata for # 3173 (saved as 3173)
#  Metadata for # 3174 (saved as 3174)
#  Metadata for # 3175 (saved as 3175)
#  Metadata for # 3176 (saved as 3176)
#  Metadata for # 3177 (saved as 3177)
#  Metadata for # 3178 (saved as 3178)
#  Metadata for # 3179 (saved as 3179)
#  Metadata for # 3180 (saved as 3180)
#  Metadata for # 3181 (saved as 3181)
#  Metadata for # 3182 (saved as 3182)
#  Metadata for # 3183 (saved as 3183)
#  Metadata for # 3184 (saved as 3184)
#  Metadata for # 3185 (saved as 3185)
#  Metadata for # 3186 (saved as 3186)
#  Metadata for # 3187 (saved as 3187)
#  Metadata for # 3188 (saved as 3188)
#  Metadata for # 3189 (saved as 3189)
#  Metadata for # 3190 (saved as 3190)
#  Metadata for # 3191 (saved as 3191)
#  Metadata for # 3192 (saved as 3192)
#  Metadata for # 3193 (saved as 3193)
#  Metadata for # 3194 (saved as 3194)
#  Metadata for # 3195 (saved as 3195)
#  Metadata for # 3196 (saved as 3196)
#  Metadata for # 3197 (saved as 3197)
#  Metadata for # 3198 (saved as 3198)
#  Metadata for # 3199 (saved as 3199)
#  Metadata for # 3200 (saved as 3200)
#  Metadata for # 3201 (saved as 3201)
#  Metadata for # 3202 (saved as 3202)
#  Metadata for # 3203 (saved as 3203)
#  Metadata for # 3204 (saved as 3204)
#  Metadata for # 3205 (saved as 3205)
#  Metadata for # 3206 (saved as 3206)
#  Metadata for # 3207 (saved as 3207)
#  Metadata for # 3208 (saved as 3208)
#  Metadata for # 3209 (saved as 3209)
#  Metadata for # 3210 (saved as 3210)
#  Metadata for # 3211 (saved as 3211)
#  Metadata for # 3212 (saved as 3212)
#  Metadata for # 3213 (saved as 3213)
#  Metadata for # 3214 (saved as 3214)
#  Metadata for # 3215 (saved as 3215)
#  Metadata for # 3216 (saved as 3216)
#  Metadata for # 3217 (saved as 3217)
#  Metadata for # 3218 (saved as 3218)
#  Metadata for # 3219 (saved as 3219)
#  Metadata for # 3220 (saved as 3220)
#  Metadata for # 3221 (saved as 3221)
#  Metadata for # 3222 (saved as 3222)
#  Metadata for # 3223 (saved as 3223)
#  Metadata for # 3224 (saved as 3224)
#  Metadata for # 3225 (saved as 3225)
#  Metadata for # 3226 (saved as 3226)
#  Metadata for # 3227 (saved as 3227)
#  Metadata for # 3228 (saved as 3228)
#  Metadata for # 3229 (saved as 3229)
#  Metadata for # 3230 (saved as 3230)
#  Metadata for # 3231 (saved as 3231)
#  Metadata for # 3232 (saved as 3232)
#  Metadata for # 3233 (saved as 3233)
#  Metadata for # 3234 (saved as 3234)
#  Metadata for # 3235 (saved as 3235)
#  Metadata for # 3236 (saved as 3236)
#  Metadata for # 3237 (saved as 3237)
#  Metadata for # 3238 (saved as 3238)
#  Metadata for # 3239 (saved as 3239)
#  Metadata for # 3240 (saved as 3240)
#  Metadata for # 3241 (saved as 3241)
#  Metadata for # 3242 (saved as 3242)
#  Metadata for # 3243 (saved as 3243)
#  Metadata for # 3244 (saved as 3244)
#  Metadata for # 3245 (saved as 3245)
#  Metadata for # 3246 (saved as 3246)
#  Metadata for # 3247 (saved as 3247)
#  Metadata for # 3248 (saved as 3248)
#  Metadata for # 3249 (saved as 3249)
#  Metadata for # 3250 (saved as 3250)
#  Metadata for # 3251 (saved as 3251)
#  Metadata for # 3252 (saved as 3252)
#  Metadata for # 3253 (saved as 3253)
#  Metadata for # 3254 (saved as 3254)
#  Metadata for # 3255 (saved as 3255)
#  Metadata for # 3256 (saved as 3256)
#  Metadata for # 3257 (saved as 3257)
#  Metadata for # 3258 (saved as 3258)
#  Metadata for # 3259 (saved as 3259)
#  Metadata for # 3260 (saved as 3260)
#  Metadata for # 3261 (saved as 3261)
#  Metadata for # 3262 (saved as 3262)
#  Metadata for # 3263 (saved as 3263)
#  Metadata for # 3264 (saved as 3264)
#  Metadata for # 3265 (saved as 3265)
#  Metadata for # 3266 (saved as 3266)
#  Metadata for # 3267 (saved as 3267)
#  Metadata for # 3268 (saved as 3268)
#  Metadata for # 3269 (saved as 3269)
#  Metadata for # 3270 (saved as 3270)
#  Metadata for # 3271 (saved as 3271)
#  Metadata for # 3272 (saved as 3272)
#  Metadata for # 3273 (saved as 3273)
#  Metadata for # 3274 (saved as 3274)
#  Metadata for # 3275 (saved as 3275)
#  Metadata for # 3276 (saved as 3276)
#  Metadata for # 3277 (saved as 3277)
#  Metadata for # 3278 (saved as 3278)
#  Metadata for # 3279 (saved as 3279)
#  Metadata for # 3280 (saved as 3280)
#  Metadata for # 3281 (saved as 3281)
#  Metadata for # 3282 (saved as 3282)
#  Metadata for # 3283 (saved as 3283)
#  Metadata for # 3284 (saved as 3284)
#  Metadata for # 3285 (saved as 3285)
#  Metadata for # 3286 (saved as 3286)
#  Metadata for # 3287 (saved as 3287)
#  Metadata for # 3288 (saved as 3288)
#  Metadata for # 3289 (saved as 3289)
#  Metadata for # 3290 (saved as 3290)
#  Metadata for # 3291 (saved as 3291)
#  Metadata for # 3292 (saved as 3292)
#  Metadata for # 3293 (saved as 3293)
#  Metadata for # 3294 (saved as 3294)
#  Metadata for # 3295 (saved as 3295)
#  Metadata for # 3296 (saved as 3296)
#  Metadata for # 3297 (saved as 3297)
#  Metadata for # 3298 (saved as 3298)
#  Metadata for # 3299 (saved as 3299)
#  Metadata for # 3300 (saved as 3300)
#  Metadata for # 3301 (saved as 3301)
#  Metadata for # 3302 (saved as 3302)
#  Metadata for # 3303 (saved as 3303)
#  Metadata for # 3304 (saved as 3304)
#  Metadata for # 3305 (saved as 3305)
#  Metadata for # 3306 (saved as 3306)
#  Metadata for # 3307 (saved as 3307)
#  Metadata for # 3308 (saved as 3308)
#  Metadata for # 3309 (saved as 3309)
#  Metadata for # 3310 (saved as 3310)
#  Metadata for # 3311 (saved as 3311)
#  Metadata for # 3312 (saved as 3312)
#  Metadata for # 3313 (saved as 3313)
#  Metadata for # 3314 (saved as 3314)
#  Metadata for # 3315 (saved as 3315)
#  Metadata for # 3316 (saved as 3316)
#  Metadata for # 3317 (saved as 3317)
#  Metadata for # 3318 (saved as 3318)
#  Metadata for # 3319 (saved as 3319)
#  Metadata for # 3320 (saved as 3320)
#  Metadata for # 3321 (saved as 3321)
#  Metadata for # 3322 (saved as 3322)
#  Metadata for # 3323 (saved as 3323)
#  Metadata for # 3324 (saved as 3324)
#  Metadata for # 3325 (saved as 3325)
#  Metadata for # 3326 (saved as 3326)
#  Metadata for # 3327 (saved as 3327)
#  Metadata for # 3328 (saved as 3328)
#  Metadata for # 3329 (saved as 3329)
#  Metadata for # 3330 (saved as 3330)
#  Metadata for # 3331 (saved as 3331)
#  Metadata for # 3332 (saved as 3332)
#  Metadata for # 3333 (saved as 3333)
#  Metadata for # 3334 (saved as 3334)
#  Metadata for # 3335 (saved as 3335)
#  Metadata for # 3336 (saved as 3336)
#  Metadata for # 3337 (saved as 3337)
#  Metadata for # 3338 (saved as 3338)
#  Metadata for # 3339 (saved as 3339)
#  Metadata for # 3340 (saved as 3340)
#  Metadata for # 3341 (saved as 3341)
#  Metadata for # 3342 (saved as 3342)
#  Metadata for # 3343 (saved as 3343)
#  Metadata for # 3344 (saved as 3344)
#  Metadata for # 3345 (saved as 3345)
#  Metadata for # 3346 (saved as 3346)
#  Metadata for # 3347 (saved as 3347)
#  Metadata for # 3348 (saved as 3348)
#  Metadata for # 3349 (saved as 3349)
#  Metadata for # 3350 (saved as 3350)
#  Metadata for # 3351 (saved as 3351)
#  Metadata for # 3352 (saved as 3352)
#  Metadata for # 3353 (saved as 3353)
#  Metadata for # 3354 (saved as 3354)
#  Metadata for # 3355 (saved as 3355)
#  Metadata for # 3356 (saved as 3356)
#  Metadata for # 3357 (saved as 3357)
#  Metadata for # 3358 (saved as 3358)
#  Metadata for # 3359 (saved as 3359)
#  Metadata for # 3360 (saved as 3360)
#  Metadata for # 3361 (saved as 3361)
#  Metadata for # 3362 (saved as 3362)
#  Metadata for # 3363 (saved as 3363)
#  Metadata for # 3364 (saved as 3364)
#  Metadata for # 3365 (saved as 3365)
#  Metadata for # 3366 (saved as 3366)
#  Metadata for # 3367 (saved as 3367)
#  Metadata for # 3368 (saved as 3368)
#  Metadata for # 3369 (saved as 3369)
#  Metadata for # 3370 (saved as 3370)
#  Metadata for # 3371 (saved as 3371)
#  Metadata for # 3372 (saved as 3372)
#  Metadata for # 3373 (saved as 3373)
#  Metadata for # 3374 (saved as 3374)
#  Metadata for # 3375 (saved as 3375)
#  Metadata for # 3376 (saved as 3376)
#  Metadata for # 3377 (saved as 3377)
#  Metadata for # 3378 (saved as 3378)
#  Metadata for # 3379 (saved as 3379)
#  Metadata for # 3380 (saved as 3380)
#  Metadata for # 3381 (saved as 3381)
#  Metadata for # 3382 (saved as 3382)
#  Metadata for # 3383 (saved as 3383)
#  Metadata for # 3384 (saved as 3384)
#  Metadata for # 3385 (saved as 3385)
#  Metadata for # 3386 (saved as 3386)
#  Metadata for # 3387 (saved as 3387)
#  Metadata for # 3388 (saved as 3388)
#  Metadata for # 3389 (saved as 3389)
#  Metadata for # 3390 (saved as 3390)
#  Metadata for # 3391 (saved as 3391)
#  Metadata for # 3392 (saved as 3392)
#  Metadata for # 3393 (saved as 3393)
#  Metadata for # 3394 (saved as 3394)
#  Metadata for # 3395 (saved as 3395)
#  Metadata for # 3396 (saved as 3396)
#  Metadata for # 3397 (saved as 3397)
#  Metadata for # 3398 (saved as 3398)
#  Metadata for # 3399 (saved as 3399)
#  Metadata for # 3400 (saved as 3400)
#  Metadata for # 3401 (saved as 3401)
#  Metadata for # 3402 (saved as 3402)
#  Metadata for # 3403 (saved as 3403)
#  Metadata for # 3404 (saved as 3404)
#  Metadata for # 3405 (saved as 3405)
#  Metadata for # 3406 (saved as 3406)
#  Metadata for # 3407 (saved as 3407)
#  Metadata for # 3408 (saved as 3408)
#  Metadata for # 3409 (saved as 3409)
#  Metadata for # 3410 (saved as 3410)
#  Metadata for # 3411 (saved as 3411)
#  Metadata for # 3412 (saved as 3412)
#  Metadata for # 3413 (saved as 3413)
#  Metadata for # 3414 (saved as 3414)
#  Metadata for # 3415 (saved as 3415)
#  Metadata for # 3416 (saved as 3416)
#  Metadata for # 3417 (saved as 3417)
#  Metadata for # 3418 (saved as 3418)
#  Metadata for # 3419 (saved as 3419)
#  Metadata for # 3420 (saved as 3420)
#  Metadata for # 3421 (saved as 3421)
#  Metadata for # 3422 (saved as 3422)
#  Metadata for # 3423 (saved as 3423)
#  Metadata for # 3424 (saved as 3424)
#  Metadata for # 3425 (saved as 3425)
#  Metadata for # 3426 (saved as 3426)
#  Metadata for # 3427 (saved as 3427)
#  Metadata for # 3428 (saved as 3428)
#  Metadata for # 3429 (saved as 3429)
#  Metadata for # 3430 (saved as 3430)
#  Metadata for # 3431 (saved as 3431)
#  Metadata for # 3432 (saved as 3432)
#  Metadata for # 3433 (saved as 3433)
#  Metadata for # 3434 (saved as 3434)
#  Metadata for # 3435 (saved as 3435)
#  Metadata for # 3436 (saved as 3436)
#  Metadata for # 3437 (saved as 3437)
#  Metadata for # 3438 (saved as 3438)
#  Metadata for # 3439 (saved as 3439)
#  Metadata for # 3440 (saved as 3440)
#  Metadata for # 3441 (saved as 3441)
#  Metadata for # 3442 (saved as 3442)
#  Metadata for # 3443 (saved as 3443)
#  Metadata for # 3444 (saved as 3444)
#  Metadata for # 3445 (saved as 3445)
#  Metadata for # 3446 (saved as 3446)
#  Metadata for # 3447 (saved as 3447)
#  Metadata for # 3448 (saved as 3448)
#  Metadata for # 3449 (saved as 3449)
#  Metadata for # 3450 (saved as 3450)
#  Metadata for # 3451 (saved as 3451)
#  Metadata for # 3452 (saved as 3452)
#  Metadata for # 3453 (saved as 3453)
#  Metadata for # 3454 (saved as 3454)
#  Metadata for # 3455 (saved as 3455)
#  Metadata for # 3456 (saved as 3456)
#  Metadata for # 3457 (saved as 3457)
#  Metadata for # 3458 (saved as 3458)
#  Metadata for # 3459 (saved as 3459)
#  Metadata for # 3460 (saved as 3460)
#  Metadata for # 3461 (saved as 3461)
#  Metadata for # 3462 (saved as 3462)
#  Metadata for # 3463 (saved as 3463)
#  Metadata for # 3464 (saved as 3464)
#  Metadata for # 3465 (saved as 3465)
#  Metadata for # 3466 (saved as 3466)
#  Metadata for # 3467 (saved as 3467)
#  Metadata for # 3468 (saved as 3468)
#  Metadata for # 3469 (saved as 3469)
#  Metadata for # 3470 (saved as 3470)
#  Metadata for # 3471 (saved as 3471)
#  Metadata for # 3472 (saved as 3472)
#  Metadata for # 3473 (saved as 3473)
#  Metadata for # 3474 (saved as 3474)
#  Metadata for # 3475 (saved as 3475)
#  Metadata for # 3476 (saved as 3476)
#  Metadata for # 3477 (saved as 3477)
#  Metadata for # 3478 (saved as 3478)
#  Metadata for # 3479 (saved as 3479)
#  Metadata for # 3480 (saved as 3480)
#  Metadata for # 3481 (saved as 3481)
#  Metadata for # 3482 (saved as 3482)
#  Metadata for # 3483 (saved as 3483)
#  Metadata for # 3484 (saved as 3484)
#  Metadata for # 3485 (saved as 3485)
#  Metadata for # 3486 (saved as 3486)
#  Metadata for # 3487 (saved as 3487)
#  Metadata for # 3488 (saved as 3488)
#  Metadata for # 3489 (saved as 3489)
#  Metadata for # 3490 (saved as 3490)
#  Metadata for # 3491 (saved as 3491)
#  Metadata for # 3492 (saved as 3492)
#  Metadata for # 3493 (saved as 3493)
#  Metadata for # 3494 (saved as 3494)
#  Metadata for # 3495 (saved as 3495)
#  Metadata for # 3496 (saved as 3496)
#  Metadata for # 3497 (saved as 3497)
#  Metadata for # 3498 (saved as 3498)
#  Metadata for # 3499 (saved as 3499)
#  Metadata for # 3500 (saved as 3500)
#  Metadata for # 3501 (saved as 3501)
#  Metadata for # 3502 (saved as 3502)
#  Metadata for # 3503 (saved as 3503)
#  Metadata for # 3504 (saved as 3504)
#  Metadata for # 3505 (saved as 3505)
#  Metadata for # 3506 (saved as 3506)
#  Metadata for # 3507 (saved as 3507)
#  Metadata for # 3508 (saved as 3508)
#  Metadata for # 3509 (saved as 3509)
#  Metadata for # 3510 (saved as 3510)
#  Metadata for # 3511 (saved as 3511)
#  Metadata for # 3512 (saved as 3512)
#  Metadata for # 3513 (saved as 3513)
#  Metadata for # 3514 (saved as 3514)
#  Metadata for # 3515 (saved as 3515)
#  Metadata for # 3516 (saved as 3516)
#  Metadata for # 3517 (saved as 3517)
#  Metadata for # 3518 (saved as 3518)
#  Metadata for # 3519 (saved as 3519)
#  Metadata for # 3520 (saved as 3520)
#  Metadata for # 3521 (saved as 3521)
#  Metadata for # 3522 (saved as 3522)
#  Metadata for # 3523 (saved as 3523)
#  Metadata for # 3524 (saved as 3524)
#  Metadata for # 3525 (saved as 3525)
#  Metadata for # 3526 (saved as 3526)
#  Metadata for # 3527 (saved as 3527)
#  Metadata for # 3528 (saved as 3528)
#  Metadata for # 3529 (saved as 3529)
#  Metadata for # 3530 (saved as 3530)
#  Metadata for # 3531 (saved as 3531)
#  Metadata for # 3532 (saved as 3532)
#  Metadata for # 3533 (saved as 3533)
#  Metadata for # 3534 (saved as 3534)
#  Metadata for # 3535 (saved as 3535)
#  Metadata for # 3536 (saved as 3536)
#  Metadata for # 3537 (saved as 3537)
#  Metadata for # 3538 (saved as 3538)
#  Metadata for # 3539 (saved as 3539)
#  Metadata for # 3540 (saved as 3540)
#  Metadata for # 3541 (saved as 3541)
#  Metadata for # 3542 (saved as 3542)
#  Metadata for # 3543 (saved as 3543)
#  Metadata for # 3544 (saved as 3544)
#  Metadata for # 3545 (saved as 3545)
#  Metadata for # 3546 (saved as 3546)
#  Metadata for # 3547 (saved as 3547)
#  Metadata for # 3548 (saved as 3548)
#  Metadata for # 3549 (saved as 3549)
#  Metadata for # 3550 (saved as 3550)
#  Metadata for # 3551 (saved as 3551)
#  Metadata for # 3552 (saved as 3552)
#  Metadata for # 3553 (saved as 3553)
#  Metadata for # 3554 (saved as 3554)
#  Metadata for # 3555 (saved as 3555)
#  Metadata for # 3556 (saved as 3556)
#  Metadata for # 3557 (saved as 3557)
#  Metadata for # 3558 (saved as 3558)
#  Metadata for # 3559 (saved as 3559)
#  Metadata for # 3560 (saved as 3560)
#  Metadata for # 3561 (saved as 3561)
#  Metadata for # 3562 (saved as 3562)
#  Metadata for # 3563 (saved as 3563)
#  Metadata for # 3564 (saved as 3564)
#  Metadata for # 3565 (saved as 3565)
#  Metadata for # 3566 (saved as 3566)
#  Metadata for # 3567 (saved as 3567)
#  Metadata for # 3568 (saved as 3568)
#  Metadata for # 3569 (saved as 3569)
#  Metadata for # 3570 (saved as 3570)
#  Metadata for # 3571 (saved as 3571)
#  Metadata for # 3572 (saved as 3572)
#  Metadata for # 3573 (saved as 3573)
#  Metadata for # 3574 (saved as 3574)
#  Metadata for # 3575 (saved as 3575)
#  Metadata for # 3576 (saved as 3576)
#  Metadata for # 3577 (saved as 3577)
#  Metadata for # 3578 (saved as 3578)
#  Metadata for # 3579 (saved as 3579)
#  Metadata for # 3580 (saved as 3580)
#  Metadata for # 3581 (saved as 3581)
#  Metadata for # 3582 (saved as 3582)
#  Metadata for # 3583 (saved as 3583)
#  Metadata for # 3584 (saved as 3584)
#  Metadata for # 3585 (saved as 3585)
#  Metadata for # 3586 (saved as 3586)
#  Metadata for # 3587 (saved as 3587)
#  Metadata for # 3588 (saved as 3588)
#  Metadata for # 3589 (saved as 3589)
#  Metadata for # 3590 (saved as 3590)
#  Metadata for # 3591 (saved as 3591)
#  Metadata for # 3592 (saved as 3592)
#  Metadata for # 3593 (saved as 3593)
#  Metadata for # 3594 (saved as 3594)
#  Metadata for # 3595 (saved as 3595)
#  Metadata for # 3596 (saved as 3596)
#  Metadata for # 3597 (saved as 3597)
#  Metadata for # 3598 (saved as 3598)
#  Metadata for # 3599 (saved as 3599)
#  Metadata for # 3600 (saved as 3600)
#  Metadata for # 3601 (saved as 3601)
#  Metadata for # 3602 (saved as 3602)
#  Metadata for # 3603 (saved as 3603)
#  Metadata for # 3604 (saved as 3604)
#  Metadata for # 3605 (saved as 3605)
#  Metadata for # 3606 (saved as 3606)
#  Metadata for # 3607 (saved as 3607)
#  Metadata for # 3608 (saved as 3608)
#  Metadata for # 3609 (saved as 3609)
#  Metadata for # 3610 (saved as 3610)
#  Metadata for # 3611 (saved as 3611)
#  Metadata for # 3612 (saved as 3612)
#  Metadata for # 3613 (saved as 3613)
#  Metadata for # 3614 (saved as 3614)
#  Metadata for # 3615 (saved as 3615)
#  Metadata for # 3616 (saved as 3616)
#  Metadata for # 3617 (saved as 3617)
#  Metadata for # 3618 (saved as 3618)
#  Metadata for # 3619 (saved as 3619)
#  Metadata for # 3620 (saved as 3620)
#  Metadata for # 3621 (saved as 3621)
#  Metadata for # 3622 (saved as 3622)
#  Metadata for # 3623 (saved as 3623)
#  Metadata for # 3624 (saved as 3624)
#  Metadata for # 3625 (saved as 3625)
#  Metadata for # 3626 (saved as 3626)
#  Metadata for # 3627 (saved as 3627)
#  Metadata for # 3628 (saved as 3628)
#  Metadata for # 3629 (saved as 3629)
#  Metadata for # 3630 (saved as 3630)
#  Metadata for # 3631 (saved as 3631)
#  Metadata for # 3632 (saved as 3632)
#  Metadata for # 3633 (saved as 3633)
#  Metadata for # 3634 (saved as 3634)
#  Metadata for # 3635 (saved as 3635)
#  Metadata for # 3636 (saved as 3636)
#  Metadata for # 3637 (saved as 3637)
#  Metadata for # 3638 (saved as 3638)
#  Metadata for # 3639 (saved as 3639)
#  Metadata for # 3640 (saved as 3640)
#  Metadata for # 3641 (saved as 3641)
#  Metadata for # 3642 (saved as 3642)
#  Metadata for # 3643 (saved as 3643)
#  Metadata for # 3644 (saved as 3644)
#  Metadata for # 3645 (saved as 3645)
#  Metadata for # 3646 (saved as 3646)
#  Metadata for # 3647 (saved as 3647)
#  Metadata for # 3648 (saved as 3648)
#  Metadata for # 3649 (saved as 3649)
#  Metadata for # 3650 (saved as 3650)
#  Metadata for # 3651 (saved as 3651)
#  Metadata for # 3652 (saved as 3652)
#  Metadata for # 3653 (saved as 3653)
#  Metadata for # 3654 (saved as 3654)
#  Metadata for # 3655 (saved as 3655)
#  Metadata for # 3656 (saved as 3656)
# ...
#  Metadata for # 6558 (saved as 6558)
#  Metadata for # 6559 (saved as 6559)
#  Metadata for # 6560 (saved as 6560)
#  Metadata for # 6561 (saved as 6561)
#  Metadata for # 6562 (saved as 6562)
#  Metadata for # 6563 (saved as 6563)
#  Metadata for # 6564 (saved as 6564)
#  Metadata for # 6565 (saved as 6565)
#  Metadata for # 6566 (saved as 6566)
#  Metadata for # 6567 (saved as 6567)
#  Metadata for # 6568 (saved as 6568)
#  Metadata for # 6569 (saved as 6569)
#  Metadata for # 6570 (saved as 6570)
#  Metadata for # 6571 (saved as 6571)
#  Metadata for # 6572 (saved as 6572)
#  Metadata for # 6573 (saved as 6573)
#  Metadata for # 6574 (saved as 6574)
#  Metadata for # 6575 (saved as 6575)
#  Metadata for # 6576 (saved as 6576)
#  Metadata for # 6577 (saved as 6577)
#  Metadata for # 6578 (saved as 6578)
#  Metadata for # 6579 (saved as 6579)
#  Metadata for # 6580 (saved as 6580)
#  Metadata for # 6581 (saved as 6581)
#  Metadata for # 6582 (saved as 6582)
#  Metadata for # 6583 (saved as 6583)
#  Metadata for # 6584 (saved as 6584)
#  Metadata for # 6585 (saved as 6585)
#  Metadata for # 6586 (saved as 6586)
#  Metadata for # 6587 (saved as 6587)
#  Metadata for # 6588 (saved as 6588)
#  Metadata for # 6589 (saved as 6589)
#  Metadata for # 6590 (saved as 6590)
#  Metadata for # 6591 (saved as 6591)
#  Metadata for # 6592 (saved as 6592)
#  Metadata for # 6593 (saved as 6593)
#  Metadata for # 6594 (saved as 6594)
#  Metadata for # 6595 (saved as 6595)
#  Metadata for # 6596 (saved as 6596)
#  Metadata for # 6597 (saved as 6597)
#  Metadata for # 6598 (saved as 6598)
#  Metadata for # 6599 (saved as 6599)
#  Metadata for # 6600 (saved as 6600)
#  Metadata for # 6601 (saved as 6601)
#  Metadata for # 6602 (saved as 6602)
#  Metadata for # 6603 (saved as 6603)
#  Metadata for # 6604 (saved as 6604)
#  Metadata for # 6605 (saved as 6605)
#  Metadata for # 6606 (saved as 6606)
#  Metadata for # 6607 (saved as 6607)
#  Metadata for # 6608 (saved as 6608)
#  Metadata for # 6609 (saved as 6609)
#  Metadata for # 6610 (saved as 6610)
#  Metadata for # 6611 (saved as 6611)
#  Metadata for # 6612 (saved as 6612)
#  Metadata for # 6613 (saved as 6613)
#  Metadata for # 6614 (saved as 6614)
#  Metadata for # 6615 (saved as 6615)
#  Metadata for # 6616 (saved as 6616)
#  Metadata for # 6617 (saved as 6617)
#  Metadata for # 6618 (saved as 6618)
#  Metadata for # 6619 (saved as 6619)
#  Metadata for # 6620 (saved as 6620)
#  Metadata for # 6621 (saved as 6621)
#  Metadata for # 6622 (saved as 6622)
#  Metadata for # 6623 (saved as 6623)
#  Metadata for # 6624 (saved as 6624)
#  Metadata for # 6625 (saved as 6625)
#  Metadata for # 6626 (saved as 6626)
#  Metadata for # 6627 (saved as 6627)
#  Metadata for # 6628 (saved as 6628)
#  Metadata for # 6629 (saved as 6629)
#  Metadata for # 6630 (saved as 6630)
#  Metadata for # 6631 (saved as 6631)
#  Metadata for # 6632 (saved as 6632)
#  Metadata for # 6633 (saved as 6633)
#  Metadata for # 6634 (saved as 6634)
#  Metadata for # 6635 (saved as 6635)
#  Metadata for # 6636 (saved as 6636)
#  Metadata for # 6637 (saved as 6637)
#  Metadata for # 6638 (saved as 6638)
#  Metadata for # 6639 (saved as 6639)
#  Metadata for # 6640 (saved as 6640)
#  Metadata for # 6641 (saved as 6641)
#  Metadata for # 6642 (saved as 6642)
#  Metadata for # 6643 (saved as 6643)
#  Metadata for # 6644 (saved as 6644)
#  Metadata for # 6645 (saved as 6645)
#  Metadata for # 6646 (saved as 6646)
#  Metadata for # 6647 (saved as 6647)
#  Metadata for # 6648 (saved as 6648)
#  Metadata for # 6649 (saved as 6649)
#  Metadata for # 6650 (saved as 6650)
#  Metadata for # 6651 (saved as 6651)
#  Metadata for # 6652 (saved as 6652)
#  Metadata for # 6653 (saved as 6653)
#  Metadata for # 6654 (saved as 6654)
#  Metadata for # 6655 (saved as 6655)
#  Metadata for # 6656 (saved as 6656)
#  Metadata for # 6657 (saved as 6657)
#  Metadata for # 6658 (saved as 6658)
#  Metadata for # 6659 (saved as 6659)
#  Metadata for # 6660 (saved as 6660)
#  Metadata for # 6661 (saved as 6661)
#  Metadata for # 6662 (saved as 6662)
#  Metadata for # 6663 (saved as 6663)
#  Metadata for # 6664 (saved as 6664)
#  Metadata for # 6665 (saved as 6665)
#  Metadata for # 6666 (saved as 6666)
#  Metadata for # 6667 (saved as 6667)
#  Metadata for # 6668 (saved as 6668)
#  Metadata for # 6669 (saved as 6669)
#  Metadata for # 6670 (saved as 6670)
#  Metadata for # 6671 (saved as 6671)
#  Metadata for # 6672 (saved as 6672)
#  Metadata for # 6673 (saved as 6673)
#  Metadata for # 6674 (saved as 6674)
#  Metadata for # 6675 (saved as 6675)
#  Metadata for # 6676 (saved as 6676)
#  Metadata for # 6677 (saved as 6677)
#  Metadata for # 6678 (saved as 6678)
#  Metadata for # 6679 (saved as 6679)
#  Metadata for # 6680 (saved as 6680)
#  Metadata for # 6681 (saved as 6681)
#  Metadata for # 6682 (saved as 6682)
#  Metadata for # 6683 (saved as 6683)
#  Metadata for # 6684 (saved as 6684)
#  Metadata for # 6685 (saved as 6685)
#  Metadata for # 6686 (saved as 6686)
#  Metadata for # 6687 (saved as 6687)
#  Metadata for # 6688 (saved as 6688)
#  Metadata for # 6689 (saved as 6689)
#  Metadata for # 6690 (saved as 6690)
#  Metadata for # 6691 (saved as 6691)
#  Metadata for # 6692 (saved as 6692)
#  Metadata for # 6693 (saved as 6693)
#  Metadata for # 6694 (saved as 6694)
#  Metadata for # 6695 (saved as 6695)
#  Metadata for # 6696 (saved as 6696)
#  Metadata for # 6697 (saved as 6697)
#  Metadata for # 6698 (saved as 6698)
#  Metadata for # 6699 (saved as 6699)
#  Metadata for # 6700 (saved as 6700)
#  Metadata for # 6701 (saved as 6701)
#  Metadata for # 6702 (saved as 6702)
#  Metadata for # 6703 (saved as 6703)
#  Metadata for # 6704 (saved as 6704)
#  Metadata for # 6705 (saved as 6705)
#  Metadata for # 6706 (saved as 6706)
#  Metadata for # 6707 (saved as 6707)
#  Metadata for # 6708 (saved as 6708)
#  Metadata for # 6709 (saved as 6709)
#  Metadata for # 6710 (saved as 6710)
#  Metadata for # 6711 (saved as 6711)
#  Metadata for # 6712 (saved as 6712)
#  Metadata for # 6713 (saved as 6713)
#  Metadata for # 6714 (saved as 6714)
#  Metadata for # 6715 (saved as 6715)
#  Metadata for # 6716 (saved as 6716)
#  Metadata for # 6717 (saved as 6717)
#  Metadata for # 6718 (saved as 6718)
#  Metadata for # 6719 (saved as 6719)
#  Metadata for # 6720 (saved as 6720)
#  Metadata for # 6721 (saved as 6721)
#  Metadata for # 6722 (saved as 6722)
#  Metadata for # 6723 (saved as 6723)
#  Metadata for # 6724 (saved as 6724)
#  Metadata for # 6725 (saved as 6725)
#  Metadata for # 6726 (saved as 6726)
#  Metadata for # 6727 (saved as 6727)
#  Metadata for # 6728 (saved as 6728)
#  Metadata for # 6729 (saved as 6729)
#  Metadata for # 6730 (saved as 6730)
#  Metadata for # 6731 (saved as 6731)
#  Metadata for # 6732 (saved as 6732)
#  Metadata for # 6733 (saved as 6733)
#  Metadata for # 6734 (saved as 6734)
#  Metadata for # 6735 (saved as 6735)
#  Metadata for # 6736 (saved as 6736)
#  Metadata for # 6737 (saved as 6737)
#  Metadata for # 6738 (saved as 6738)
#  Metadata for # 6739 (saved as 6739)
#  Metadata for # 6740 (saved as 6740)
#  Metadata for # 6741 (saved as 6741)
#  Metadata for # 6742 (saved as 6742)
#  Metadata for # 6743 (saved as 6743)
#  Metadata for # 6744 (saved as 6744)
#  Metadata for # 6745 (saved as 6745)
#  Metadata for # 6746 (saved as 6746)
#  Metadata for # 6747 (saved as 6747)
#  Metadata for # 6748 (saved as 6748)
#  Metadata for # 6749 (saved as 6749)
#  Metadata for # 6750 (saved as 6750)
#  Metadata for # 6751 (saved as 6751)
#  Metadata for # 6752 (saved as 6752)
#  Metadata for # 6753 (saved as 6753)
#  Metadata for # 6754 (saved as 6754)
#  Metadata for # 6755 (saved as 6755)
#  Metadata for # 6756 (saved as 6756)
#  Metadata for # 6757 (saved as 6757)
#  Metadata for # 6758 (saved as 6758)
#  Metadata for # 6759 (saved as 6759)
#  Metadata for # 6760 (saved as 6760)
#  Metadata for # 6761 (saved as 6761)
#  Metadata for # 6762 (saved as 6762)
#  Metadata for # 6763 (saved as 6763)
#  Metadata for # 6764 (saved as 6764)
#  Metadata for # 6765 (saved as 6765)
#  Metadata for # 6766 (saved as 6766)
#  Metadata for # 6767 (saved as 6767)
#  Metadata for # 6768 (saved as 6768)
#  Metadata for # 6769 (saved as 6769)
#  Metadata for # 6770 (saved as 6770)
#  Metadata for # 6771 (saved as 6771)
#  Metadata for # 6772 (saved as 6772)
#  Metadata for # 6773 (saved as 6773)
#  Metadata for # 6774 (saved as 6774)
#  Metadata for # 6775 (saved as 6775)
#  Metadata for # 6776 (saved as 6776)
#  Metadata for # 6777 (saved as 6777)
#  Metadata for # 6778 (saved as 6778)
#  Metadata for # 6779 (saved as 6779)
#  Metadata for # 6780 (saved as 6780)
#  Metadata for # 6781 (saved as 6781)
#  Metadata for # 6782 (saved as 6782)
#  Metadata for # 6783 (saved as 6783)
#  Metadata for # 6784 (saved as 6784)
#  Metadata for # 6785 (saved as 6785)
#  Metadata for # 6786 (saved as 6786)
#  Metadata for # 6787 (saved as 6787)
#  Metadata for # 6788 (saved as 6788)
#  Metadata for # 6789 (saved as 6789)
#  Metadata for # 6790 (saved as 6790)
#  Metadata for # 6791 (saved as 6791)
#  Metadata for # 6792 (saved as 6792)
#  Metadata for # 6793 (saved as 6793)
#  Metadata for # 6794 (saved as 6794)
#  Metadata for # 6795 (saved as 6795)
#  Metadata for # 6796 (saved as 6796)
#  Metadata for # 6797 (saved as 6797)
#  Metadata for # 6798 (saved as 6798)
#  Metadata for # 6799 (saved as 6799)
#  Metadata for # 6800 (saved as 6800)
#  Metadata for # 6801 (saved as 6801)
#  Metadata for # 6802 (saved as 6802)
#  Metadata for # 6803 (saved as 6803)
#  Metadata for # 6804 (saved as 6804)
#  Metadata for # 6805 (saved as 6805)
#  Metadata for # 6806 (saved as 6806)
#  Metadata for # 6807 (saved as 6807)
#  Metadata for # 6808 (saved as 6808)
#  Metadata for # 6809 (saved as 6809)
#  Metadata for # 6810 (saved as 6810)
#  Metadata for # 6811 (saved as 6811)
#  Metadata for # 6812 (saved as 6812)
#  Metadata for # 6813 (saved as 6813)
#  Metadata for # 6814 (saved as 6814)
#  Metadata for # 6815 (saved as 6815)
#  Metadata for # 6816 (saved as 6816)
#  Metadata for # 6817 (saved as 6817)
#  Metadata for # 6818 (saved as 6818)
#  Metadata for # 6819 (saved as 6819)
#  Metadata for # 6820 (saved as 6820)
#  Metadata for # 6821 (saved as 6821)
#  Metadata for # 6822 (saved as 6822)
#  Metadata for # 6823 (saved as 6823)
#  Metadata for # 6824 (saved as 6824)
#  Metadata for # 6825 (saved as 6825)
#  Metadata for # 6826 (saved as 6826)
#  Metadata for # 6827 (saved as 6827)
#  Metadata for # 6828 (saved as 6828)
#  Metadata for # 6829 (saved as 6829)
#  Metadata for # 6830 (saved as 6830)
#  Metadata for # 6831 (saved as 6831)
#  Metadata for # 6832 (saved as 6832)
#  Metadata for # 6833 (saved as 6833)
#  Metadata for # 6834 (saved as 6834)
#  Metadata for # 6835 (saved as 6835)
#  Metadata for # 6836 (saved as 6836)
#  Metadata for # 6837 (saved as 6837)
#  Metadata for # 6838 (saved as 6838)
#  Metadata for # 6839 (saved as 6839)
#  Metadata for # 6840 (saved as 6840)
#  Metadata for # 6841 (saved as 6841)
#  Metadata for # 6842 (saved as 6842)
#  Metadata for # 6843 (saved as 6843)
#  Metadata for # 6844 (saved as 6844)
#  Metadata for # 6845 (saved as 6845)
#  Metadata for # 6846 (saved as 6846)
#  Metadata for # 6847 (saved as 6847)
#  Metadata for # 6848 (saved as 6848)
#  Metadata for # 6849 (saved as 6849)
#  Metadata for # 6850 (saved as 6850)
#  Metadata for # 6851 (saved as 6851)
#  Metadata for # 6852 (saved as 6852)
#  Metadata for # 6853 (saved as 6853)
#  Metadata for # 6854 (saved as 6854)
#  Metadata for # 6855 (saved as 6855)
#  Metadata for # 6856 (saved as 6856)
#  Metadata for # 6857 (saved as 6857)
#  Metadata for # 6858 (saved as 6858)
#  Metadata for # 6859 (saved as 6859)
#  Metadata for # 6860 (saved as 6860)
#  Metadata for # 6861 (saved as 6861)
#  Metadata for # 6862 (saved as 6862)
#  Metadata for # 6863 (saved as 6863)
#  Metadata for # 6864 (saved as 6864)
#  Metadata for # 6865 (saved as 6865)
#  Metadata for # 6866 (saved as 6866)
#  Metadata for # 6867 (saved as 6867)
#  Metadata for # 6868 (saved as 6868)
#  Metadata for # 6869 (saved as 6869)
#  Metadata for # 6870 (saved as 6870)
#  Metadata for # 6871 (saved as 6871)
#  Metadata for # 6872 (saved as 6872)
#  Metadata for # 6873 (saved as 6873)
#  Metadata for # 6874 (saved as 6874)
#  Metadata for # 6875 (saved as 6875)
#  Metadata for # 6876 (saved as 6876)
#  Metadata for # 6877 (saved as 6877)
#  Metadata for # 6878 (saved as 6878)
#  Metadata for # 6879 (saved as 6879)
#  Metadata for # 6880 (saved as 6880)
#  Metadata for # 6881 (saved as 6881)
#  Metadata for # 6882 (saved as 6882)
#  Metadata for # 6883 (saved as 6883)
#  Metadata for # 6884 (saved as 6884)
#  Metadata for # 6885 (saved as 6885)
#  Metadata for # 6886 (saved as 6886)
#  Metadata for # 6887 (saved as 6887)
#  Metadata for # 6888 (saved as 6888)
#  Metadata for # 6889 (saved as 6889)
#  Metadata for # 6890 (saved as 6890)
#  Metadata for # 6891 (saved as 6891)
#  Metadata for # 6892 (saved as 6892)
#  Metadata for # 6893 (saved as 6893)
#  Metadata for # 6894 (saved as 6894)
#  Metadata for # 6895 (saved as 6895)
#  Metadata for # 6896 (saved as 6896)
#  Metadata for # 6897 (saved as 6897)
#  Metadata for # 6898 (saved as 6898)
#  Metadata for # 6899 (saved as 6899)
#  Metadata for # 6900 (saved as 6900)
#  Metadata for # 6901 (saved as 6901)
#  Metadata for # 6902 (saved as 6902)
#  Metadata for # 6903 (saved as 6903)
#  Metadata for # 6904 (saved as 6904)
#  Metadata for # 6905 (saved as 6905)
#  Metadata for # 6906 (saved as 6906)
#  Metadata for # 6907 (saved as 6907)
#  Metadata for # 6908 (saved as 6908)
#  Metadata for # 6909 (saved as 6909)
#  Metadata for # 6910 (saved as 6910)
#  Metadata for # 6911 (saved as 6911)
#  Metadata for # 6912 (saved as 6912)
#  Metadata for # 6913 (saved as 6913)
#  Metadata for # 6914 (saved as 6914)
#  Metadata for # 6915 (saved as 6915)
#  Metadata for # 6916 (saved as 6916)
#  Metadata for # 6917 (saved as 6917)
#  Metadata for # 6918 (saved as 6918)
#  Metadata for # 6919 (saved as 6919)
#  Metadata for # 6920 (saved as 6920)
#  Metadata for # 6921 (saved as 6921)
#  Metadata for # 6922 (saved as 6922)
#  Metadata for # 6923 (saved as 6923)
#  Metadata for # 6924 (saved as 6924)
#  Metadata for # 6925 (saved as 6925)
#  Metadata for # 6926 (saved as 6926)
#  Metadata for # 6927 (saved as 6927)
#  Metadata for # 6928 (saved as 6928)
#  Metadata for # 6929 (saved as 6929)
#  Metadata for # 6930 (saved as 6930)
#  Metadata for # 6931 (saved as 6931)
#  Metadata for # 6932 (saved as 6932)
#  Metadata for # 6933 (saved as 6933)
#  Metadata for # 6934 (saved as 6934)
#  Metadata for # 6935 (saved as 6935)
#  Metadata for # 6936 (saved as 6936)
#  Metadata for # 6937 (saved as 6937)
#  Metadata for # 6938 (saved as 6938)
#  Metadata for # 6939 (saved as 6939)
#  Metadata for # 6940 (saved as 6940)
#  Metadata for # 6941 (saved as 6941)
#  Metadata for # 6942 (saved as 6942)
#  Metadata for # 6943 (saved as 6943)
#  Metadata for # 6944 (saved as 6944)
#  Metadata for # 6945 (saved as 6945)
#  Metadata for # 6946 (saved as 6946)
#  Metadata for # 6947 (saved as 6947)
#  Metadata for # 6948 (saved as 6948)
#  Metadata for # 6949 (saved as 6949)
#  Metadata for # 6950 (saved as 6950)
#  Metadata for # 6951 (saved as 6951)
#  Metadata for # 6952 (saved as 6952)
#  Metadata for # 6953 (saved as 6953)
#  Metadata for # 6954 (saved as 6954)
#  Metadata for # 6955 (saved as 6955)
#  Metadata for # 6956 (saved as 6956)
#  Metadata for # 6957 (saved as 6957)
#  Metadata for # 6958 (saved as 6958)
#  Metadata for # 6959 (saved as 6959)
#  Metadata for # 6960 (saved as 6960)
#  Metadata for # 6961 (saved as 6961)
#  Metadata for # 6962 (saved as 6962)
#  Metadata for # 6963 (saved as 6963)
#  Metadata for # 6964 (saved as 6964)
#  Metadata for # 6965 (saved as 6965)
#  Metadata for # 6966 (saved as 6966)
#  Metadata for # 6967 (saved as 6967)
#  Metadata for # 6968 (saved as 6968)
#  Metadata for # 6969 (saved as 6969)
#  Metadata for # 6970 (saved as 6970)
#  Metadata for # 6971 (saved as 6971)
#  Metadata for # 6972 (saved as 6972)
#  Metadata for # 6973 (saved as 6973)
#  Metadata for # 6974 (saved as 6974)
#  Metadata for # 6975 (saved as 6975)
#  Metadata for # 6976 (saved as 6976)
#  Metadata for # 6977 (saved as 6977)
#  Metadata for # 6978 (saved as 6978)
#  Metadata for # 6979 (saved as 6979)
#  Metadata for # 6980 (saved as 6980)
#  Metadata for # 6981 (saved as 6981)
#  Metadata for # 6982 (saved as 6982)
#  Metadata for # 6983 (saved as 6983)
#  Metadata for # 6984 (saved as 6984)
#  Metadata for # 6985 (saved as 6985)
#  Metadata for # 6986 (saved as 6986)
#  Metadata for # 6987 (saved as 6987)
#  Metadata for # 6988 (saved as 6988)
#  Metadata for # 6989 (saved as 6989)

# %%
# print(item_info)
# reviews_df = reviews_df.append(item_info,ignore_index=True)
# print(reviews_df.iloc[-1])
reviews_df.to_csv('review_db.csv')
# print(reviews_df.shape[0]-1)

# %%
print('Done!')
# print(x)
# fname = 'review_db.csv'
# reviews_df = pd.read_csv(fname)
# print(isinstance(reviews_df['Name'][url_ix],str))
# reviews_df.to_csv('review_db2.csv')
# Out:
# Done!

# %%
# Get reviews by replacing /dp/ with /product-reviews/ in the url!

# with open(out_dir+'product_urls.txt','r') as myf:
#     product_urls = myf.readlines()
product_urls = np.loadtxt(out_dir+'product_urls.txt',dtype=str)

# Set up the pandas array
reviews_df = scraper_tools.get_database()

for product_ix in np.arange(1,997):
    
    product_url = product_urls[product_ix]
    
    n_reviews = int(reviews_df['n_reviews'][product_ix].split(' ')[0])
    
    n_pages = np.ceil(n_reviews/10).astype(int)
    
    all_ratings = []
    all_reviews = []
    
    print('  Product {0}: {1} pages'.format(product_ix,n_pages))
    
    for page_ix in range(n_pages):
        
        # Navigate to page
        review_url = product_url.replace('/dp/','/product-review/')
        review_url += '/ref=cm_cr_arp_d_paging_btm_2?ie=UTF8&pageNumber={0}'.format(page_ix+1) # starts at 1
        driver.get(review_url)
        
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        
        # Loop through reviews on the page
        reviews_on_page = soup.findAll('div',attrs={'data-hook':'review'})
        for r in reviews_on_page:
            # Get the star rating
            rating_text = r.find('i',attrs={'data-hook':"review-star-rating"}).getText()
            rating = float(rating_text[0:2])
            all_ratings.append(rating)

            # Get the review text
            review_text = r.find('span',attrs={'data-hook':"review-body"}).getText()
            all_reviews.append(review_text)
        
        wait(amount=1)
        
        product_df = pd.DataFrame({'ReviewRatings':all_ratings,'Reviews':all_reviews})
        product_df.to_csv(out_dir+'product_{0:05}.csv'.format(product_ix))
#         reviews_df['Reviews'][product_ix] = all_reviews
#         reviews_df['ReviewRatings'][product_ix] = all_ratings
        #Save it
#         reviews_df.to_csv('review_db2.csv')
# Out:
#   Product 1: 31 pages
#   Product 2: 10 pages
#   Product 3: 87 pages
#   Product 4: 14 pages
#   Product 5: 9 pages
#   Product 6: 9 pages
#   Product 7: 2 pages
#   Product 8: 31 pages
#   Product 9: 6 pages
#   Product 10: 1 pages
#   Product 11: 5 pages
#   Product 12: 12 pages
#   Product 13: 51 pages
#   Product 14: 10 pages
#   Product 15: 1 pages
#   Product 16: 5 pages
#   Product 17: 15 pages
#   Product 18: 9 pages
#   Product 19: 1 pages
#   Product 20: 30 pages
#   Product 21: 27 pages
#   Product 22: 4 pages
#   Product 23: 5 pages
#   Product 24: 1 pages
#   Product 25: 13 pages
#   Product 26: 8 pages
#   Product 27: 4 pages
#   Product 28: 1 pages
#   Product 29: 85 pages
#   Product 30: 40 pages
#   Product 31: 3 pages
#   Product 32: 2 pages
#   Product 33: 1 pages
#   Product 34: 12 pages
#   Product 35: 7 pages
#   Product 36: 11 pages
#   Product 37: 2 pages
#   Product 38: 2 pages
#   Product 39: 13 pages
#   Product 40: 19 pages
#   Product 41: 7 pages
#   Product 42: 1 pages
#   Product 43: 31 pages
#   Product 44: 19 pages
#   Product 45: 5 pages
#   Product 46: 31 pages
#   Product 47: 16 pages
#   Product 48: 19 pages
#   Product 49: 17 pages
#   Product 50: 1 pages
#   Product 51: 11 pages
#   Product 52: 7 pages
#   Product 53: 7 pages
#   Product 54: 2 pages
#   Product 55: 33 pages
#   Product 56: 2 pages
#   Product 57: 1 pages
#   Product 58: 2 pages
#   Product 59: 29 pages
#   Product 60: 45 pages
#   Product 61: 2 pages
#   Product 62: 7 pages
#   Product 63: 6 pages
#   Product 64: 26 pages
#   Product 65: 5 pages
#   Product 66: 2 pages
#   Product 67: 17 pages
#   Product 68: 13 pages
#   Product 69: 3 pages
#   Product 70: 2 pages
#   Product 71: 18 pages
#   Product 72: 3 pages
#   Product 73: 2 pages
#   Product 74: 2 pages
#   Product 75: 6 pages
#   Product 76: 2 pages
#   Product 77: 7 pages
#   Product 78: 6 pages
#   Product 79: 2 pages
#   Product 80: 3 pages
#   Product 81: 22 pages
#   Product 82: 7 pages
#   Product 83: 5 pages
#   Product 84: 4 pages
#   Product 85: 7 pages
#   Product 86: 16 pages
#   Product 87: 11 pages
#   Product 88: 1 pages
#   Product 89: 3 pages
#   Product 90: 10 pages
#   Product 91: 4 pages
#   Product 92: 19 pages
#   Product 93: 6 pages
#   Product 94: 17 pages
#   Product 95: 7 pages
#   Product 96: 6 pages
#   Product 97: 2 pages
#   Product 98: 4 pages
#   Product 99: 6 pages
#   Product 100: 2 pages
#   Product 101: 18 pages
#   Product 102: 1 pages
#   Product 103: 2 pages
#   Product 104: 8 pages
#   Product 105: 26 pages
#   Product 106: 4 pages
#   Product 107: 5 pages
#   Product 108: 3 pages
#   Product 109: 5 pages
#   Product 110: 18 pages
#   Product 111: 9 pages
#   Product 112: 5 pages

# %%
# print(len(all_ratings))
# print(reviews_df['Reviews'][0:5].dtype)
print(n_reviews)
print(n_pages)
# Out:
# 5
# 0
